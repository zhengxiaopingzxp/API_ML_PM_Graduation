# %%
from aip import AipImageClassify
from IPython.display import Image
""" 你的 APPID AK SK """
APP_ID = '17907381'
API_KEY = 'd3oQtpNIcRZCGHrGZFtQxzbp'
SECRET_KEY = '6V8YFyW1raPRQsN28rOY7hXUR11bScN2'

client = AipImageClassify(APP_ID, API_KEY, SECRET_KEY)

# %%
Image(filename =r'C:\Users\Administrator\Desktop\1.jpg', width=100, height=100)

# %%
""" 读取图片 """
def get_file_content(filePath):
    with open(filePath, 'rb') as fp:
        return fp.read()

image = get_file_content(r'C:\Users\Administrator\Desktop\1.jpg')

""" 调用地标识别 """
client.landmark(image)
# Out:
# {'log_id': 4136280335253860802, 'result': {'landmark': '广州塔'}}
